# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description":description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ulaangom
# Processing Record 2 of Set 1 | taoudenni
# Processing Record 3 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | pinega
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | buala
# Processing Record 9 of Set 1 | constitucion
# Processing Record 10 of Set 1 | liuhe
# Processing Record 11 of Set 1 | tual
# Processing Record 12 of Set 1 | eyl
# Processing Record 13 of Set 1 | longyearbyen
# Processing Record 14 of Set 1 | fortuna
# Processing Record 15 of Set 1 | torbay
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | shingu
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | tymovskoye
# Processing Record 21 of Set 1 | sao joao da barra
# Processing Record 22 of Set 1 | puerto cabezas
# Processing Record 23 of Set 1 | dauphin
# Processing Record 24 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 1 | virginia beach
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | yar-sale
# Processing Record 28 of Set 1 | sakakah
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 1 | redmond
# Processing Record 33 of Set 1 | saskylakh
# Processing Record 34 of Set 1 | banmo
# City not found. Skipping...
# Processing Record 35 of Set 1 | muros
# Processing Record 36 of Set 1 | dabhol
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | itoman
# Processing Record 40 of Set 1 | beloha
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | qandahar
# City not found. Skipping...
# Processing Record 43 of Set 1 | salalah
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | namatanai
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | lufilufi
# Processing Record 48 of Set 1 | hamilton
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | esperance
# Processing Record 3 of Set 2 | victoria
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | leningradskiy
# Processing Record 7 of Set 2 | rosarito
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | nara
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | kirakira
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | ostrovnoy
# Processing Record 18 of Set 2 | luang prabang
# Processing Record 19 of Set 2 | cayambe
# Processing Record 20 of Set 2 | basqal
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | bell ville
# Processing Record 23 of Set 2 | ayagoz
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | astana
# Processing Record 26 of Set 2 | shimoda
# Processing Record 27 of Set 2 | vysokogornyy
# Processing Record 28 of Set 2 | vestmanna
# Processing Record 29 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 2 | sainte-maxime
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | chirongui
# Processing Record 34 of Set 2 | hualmay
# Processing Record 35 of Set 2 | marawi
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | pisco
# Processing Record 38 of Set 2 | bulgan
# Processing Record 39 of Set 2 | garowe
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | port blair
# Processing Record 42 of Set 2 | touros
# Processing Record 43 of Set 2 | kerouane
# Processing Record 44 of Set 2 | abu dhabi
# Processing Record 45 of Set 2 | sambava
# Processing Record 46 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 2 | tura
# Processing Record 48 of Set 2 | nanortalik
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | mahebourg
# Processing Record 2 of Set 3 | niteroi
# Processing Record 3 of Set 3 | morros
# Processing Record 4 of Set 3 | fairbanks
# Processing Record 5 of Set 3 | ushuaia
# Processing Record 6 of Set 3 | dunedin
# Processing Record 7 of Set 3 | baiquan
# Processing Record 8 of Set 3 | hasaki
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | chuy
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | clyde river
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 3 | cidreira
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | gillette
# Processing Record 18 of Set 3 | ulaanbaatar
# Processing Record 19 of Set 3 | yagodnoye
# Processing Record 20 of Set 3 | inhambane
# Processing Record 21 of Set 3 | punta arenas
# Processing Record 22 of Set 3 | katherine
# Processing Record 23 of Set 3 | westport
# Processing Record 24 of Set 3 | okha
# Processing Record 25 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 3 | poum
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | chokurdakh
# Processing Record 30 of Set 3 | vardo
# Processing Record 31 of Set 3 | erenhot
# Processing Record 32 of Set 3 | esparta
# Processing Record 33 of Set 3 | florianopolis
# Processing Record 34 of Set 3 | margate
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | bahia honda
# Processing Record 37 of Set 3 | flinders
# Processing Record 38 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | krasnogorsk
# Processing Record 41 of Set 3 | robe
# Processing Record 42 of Set 3 | korla
# Processing Record 43 of Set 3 | mataura
# Processing Record 44 of Set 3 | coihaique
# Processing Record 45 of Set 3 | chabahar
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | aklavik
# Processing Record 48 of Set 3 | yulara
# Processing Record 49 of Set 3 | kununurra
# Processing Record 50 of Set 3 | yatou
# Processing Record 1 of Set 4 | preobrazheniye
# Processing Record 2 of Set 4 | bengkulu
# Processing Record 3 of Set 4 | mar del plata
# Processing Record 4 of Set 4 | tamandare
# Processing Record 5 of Set 4 | kalaleh
# Processing Record 6 of Set 4 | acari
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | faya
# Processing Record 9 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 4 | hilo
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | saint-francois
# Processing Record 14 of Set 4 | tarakan
# Processing Record 15 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 4 | wasilla
# Processing Record 17 of Set 4 | san policarpo
# Processing Record 18 of Set 4 | pacific grove
# Processing Record 19 of Set 4 | kenai
# Processing Record 20 of Set 4 | dingle
# Processing Record 21 of Set 4 | iwanai
# Processing Record 22 of Set 4 | san patricio
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | mirnyy
# Processing Record 25 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | laguna
# Processing Record 27 of Set 4 | kozulka
# Processing Record 28 of Set 4 | hazorasp
# Processing Record 29 of Set 4 | karlshamn
# Processing Record 30 of Set 4 | maningrida
# Processing Record 31 of Set 4 | rio gallegos
# Processing Record 32 of Set 4 | abha
# Processing Record 33 of Set 4 | severo-kurilsk
# Processing Record 34 of Set 4 | adrar
# Processing Record 35 of Set 4 | mayo
# Processing Record 36 of Set 4 | uruzgan
# Processing Record 37 of Set 4 | ola
# Processing Record 38 of Set 4 | polson
# Processing Record 39 of Set 4 | iraquara
# Processing Record 40 of Set 4 | miramar
# Processing Record 41 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 4 | saint anthony
# Processing Record 43 of Set 4 | leh
# Processing Record 44 of Set 4 | port lincoln
# Processing Record 45 of Set 4 | arraial do cabo
# Processing Record 46 of Set 4 | mnogovershinnyy
# Processing Record 47 of Set 4 | parana
# Processing Record 48 of Set 4 | yankton
# Processing Record 49 of Set 4 | rosario
# Processing Record 50 of Set 4 | egvekinot
# Processing Record 1 of Set 5 | drumheller
# Processing Record 2 of Set 5 | barrow
# Processing Record 3 of Set 5 | zhiryatino
# Processing Record 4 of Set 5 | nenjiang
# Processing Record 5 of Set 5 | horom
# Processing Record 6 of Set 5 | dinguiraye
# Processing Record 7 of Set 5 | lata
# Processing Record 8 of Set 5 | paita
# Processing Record 9 of Set 5 | santa maria
# Processing Record 10 of Set 5 | buraydah
# Processing Record 11 of Set 5 | butaritari
# Processing Record 12 of Set 5 | deep river
# Processing Record 13 of Set 5 | soyo
# Processing Record 14 of Set 5 | port elizabeth
# Processing Record 15 of Set 5 | talnakh
# Processing Record 16 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 5 | kutum
# Processing Record 18 of Set 5 | ketchikan
# Processing Record 19 of Set 5 | mantua
# Processing Record 20 of Set 5 | labuhan
# Processing Record 21 of Set 5 | zhangjiakou
# Processing Record 22 of Set 5 | libreville
# Processing Record 23 of Set 5 | khatanga
# Processing Record 24 of Set 5 | mount isa
# Processing Record 25 of Set 5 | singapore
# Processing Record 26 of Set 5 | hovd
# Processing Record 27 of Set 5 | champerico
# Processing Record 28 of Set 5 | souillac
# Processing Record 29 of Set 5 | san quintin
# Processing Record 30 of Set 5 | ust-tsilma
# Processing Record 31 of Set 5 | sena madureira
# Processing Record 32 of Set 5 | amurzet
# Processing Record 33 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 34 of Set 5 | burgeo
# Processing Record 35 of Set 5 | provideniya
# Processing Record 36 of Set 5 | lac du bonnet
# Processing Record 37 of Set 5 | nishihara
# Processing Record 38 of Set 5 | carnarvon
# Processing Record 39 of Set 5 | ballina
# Processing Record 40 of Set 5 | dali
# Processing Record 41 of Set 5 | alindao
# Processing Record 42 of Set 5 | bireun
# Processing Record 43 of Set 5 | cap malheureux
# Processing Record 44 of Set 5 | sao filipe
# Processing Record 45 of Set 5 | acapulco
# Processing Record 46 of Set 5 | amposta
# Processing Record 47 of Set 5 | mao
# Processing Record 48 of Set 5 | san rafael del sur
# Processing Record 49 of Set 5 | samarai
# Processing Record 50 of Set 5 | rock sound
# Processing Record 1 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 6 | kieta
# Processing Record 3 of Set 6 | kavaratti
# Processing Record 4 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 6 | pandan
# Processing Record 6 of Set 6 | natal
# Processing Record 7 of Set 6 | jati
# Processing Record 8 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 6 | black river
# Processing Record 10 of Set 6 | cairns
# Processing Record 11 of Set 6 | zakharovo
# Processing Record 12 of Set 6 | tasiilaq
# Processing Record 13 of Set 6 | chyhyryn
# Processing Record 14 of Set 6 | the valley
# Processing Record 15 of Set 6 | kuala terengganu
# Processing Record 16 of Set 6 | lorengau
# Processing Record 17 of Set 6 | guymon
# Processing Record 18 of Set 6 | eureka
# Processing Record 19 of Set 6 | tecoanapa
# Processing Record 20 of Set 6 | katobu
# Processing Record 21 of Set 6 | east wemyss
# Processing Record 22 of Set 6 | dakar
# Processing Record 23 of Set 6 | kuvandyk
# Processing Record 24 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 25 of Set 6 | bayanday
# Processing Record 26 of Set 6 | geraldton
# Processing Record 27 of Set 6 | camacha
# Processing Record 28 of Set 6 | santa rosa
# Processing Record 29 of Set 6 | cayenne
# Processing Record 30 of Set 6 | tabou
# Processing Record 31 of Set 6 | nelson bay
# Processing Record 32 of Set 6 | santiago
# Processing Record 33 of Set 6 | asau
# Processing Record 34 of Set 6 | san cristobal
# Processing Record 35 of Set 6 | heyang
# Processing Record 36 of Set 6 | vila velha
# Processing Record 37 of Set 6 | chapais
# Processing Record 38 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 39 of Set 6 | ocozocoautla
# City not found. Skipping...
# Processing Record 40 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 6 | paamiut
# Processing Record 42 of Set 6 | lagoa
# Processing Record 43 of Set 6 | chernyshevsk
# Processing Record 44 of Set 6 | bilibino
# Processing Record 45 of Set 6 | kurilsk
# Processing Record 46 of Set 6 | morant bay
# Processing Record 47 of Set 6 | faanui
# Processing Record 48 of Set 6 | araguari
# Processing Record 49 of Set 6 | cherskiy
# Processing Record 50 of Set 6 | omsukchan
# Processing Record 1 of Set 7 | anloga
# Processing Record 2 of Set 7 | guerrero negro
# Processing Record 3 of Set 7 | ranong
# Processing Record 4 of Set 7 | ornskoldsvik
# Processing Record 5 of Set 7 | bambanglipuro
# Processing Record 6 of Set 7 | north bend
# Processing Record 7 of Set 7 | portland
# Processing Record 8 of Set 7 | surt
# Processing Record 9 of Set 7 | rumat heib
# Processing Record 10 of Set 7 | viedma
# Processing Record 11 of Set 7 | tautira
# Processing Record 12 of Set 7 | nikolskoye
# Processing Record 13 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 14 of Set 7 | angoche
# Processing Record 15 of Set 7 | zaraza
# Processing Record 16 of Set 7 | kenora
# Processing Record 17 of Set 7 | castro
# Processing Record 18 of Set 7 | buchanan
# Processing Record 19 of Set 7 | khasan
# Processing Record 20 of Set 7 | tucuman
# Processing Record 21 of Set 7 | shelburne
# Processing Record 22 of Set 7 | fort nelson
# Processing Record 23 of Set 7 | savannah bight
# Processing Record 24 of Set 7 | totton
# Processing Record 25 of Set 7 | cubulco
# Processing Record 26 of Set 7 | morondava
# Processing Record 27 of Set 7 | tuatapere
# Processing Record 28 of Set 7 | harper
# Processing Record 29 of Set 7 | kewanee
# Processing Record 30 of Set 7 | tshane
# Processing Record 31 of Set 7 | kibre mengist
# Processing Record 32 of Set 7 | suhindol
# Processing Record 33 of Set 7 | burns lake
# Processing Record 34 of Set 7 | sinnamary
# Processing Record 35 of Set 7 | georgiyevka
# Processing Record 36 of Set 7 | caravelas
# Processing Record 37 of Set 7 | beyneu
# Processing Record 38 of Set 7 | imperial
# Processing Record 39 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 7 | akyab
# Processing Record 41 of Set 7 | zadar
# Processing Record 42 of Set 7 | aleksandrov gay
# Processing Record 43 of Set 7 | saint-augustin
# Processing Record 44 of Set 7 | rennes
# Processing Record 45 of Set 7 | andenes
# Processing Record 46 of Set 7 | contai
# Processing Record 47 of Set 7 | klaksvik
# Processing Record 48 of Set 7 | ushtobe
# Processing Record 49 of Set 7 | krasnoselkup
# Processing Record 50 of Set 7 | lingao

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
